# %%
import numpy as np
import seaborn as sns

# %%
# Loading Data:
import pandas as pd

try: # Running Locally, yakinkan "file_" berada di folder "data"
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfB = pd.read_csv("data/bogor.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
    dfX = pd.read_csv("data/bekasi.csv", low_memory = False, encoding='utf8')    
except: # Running in Google Colab
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/jakarta.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/depok.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/bogor.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/tangerang.csv
    # !wget -P data/ https://raw.githubusercontent.com/taufiksutanto/ADM-Case-01-EDA/master/data/bekasi.csv
    dfJ = pd.read_csv("data/jakarta.csv", low_memory = False, encoding='utf8')
    dfD = pd.read_csv("data/depok.csv", low_memory = False, encoding='utf8')
    dfB = pd.read_csv("data/bogor.csv", low_memory = False, encoding='utf8')
    dfT = pd.read_csv("data/tangerang.csv", low_memory = False, encoding='utf8')
    dfX = pd.read_csv("data/bekasi.csv", low_memory = False, encoding='utf8')
    
dfJ.shape, dfD.shape, dfB.shape, dfT.shape, dfX.shape
# Out:
# ((1024, 26), (998, 26), (999, 26), (128, 26), (992, 26))

# %% [markdown]
# # Jakarta

# %%
dfJ.head()
# Out:
#    created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0  06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1  02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2  06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3  06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4  06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
#
#   sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 1        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 2        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 3        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 4        SHM   2200.0  ...         NaN          NaN         NaN         NaN
#
#    Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 25
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 26 columns]

# %%
dfJ.drop(dfJ.iloc[:,14:], axis=1, inplace=True)
dfJ.columns
# Out:
# Index(['created_at', 'LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi',
#        'sertifikat', 'listrik', 'hadap', 'harga', 'URL', 'deskripsi'],
#       dtype='object')

# %%
dfJ1 = dfJ.iloc[:121,:]
dfJ1.tail(10)
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 111  25-11-2021   86.0   45.0  2.0  1.0     1.0      1.0  Jakarta Timur
# 112  24-11-2021   96.0   69.0  3.0  3.0     NaN      NaN  Jakarta Timur
# 113  22-11-2021   67.0  134.0  3.0  2.0     NaN      1.0  Jakarta Timur
# 114  02-12-2021  122.0  160.0  5.0  5.0     NaN      2.0  Jakarta Timur
# 115  06-12-2021   90.0   90.0  3.0  2.0     NaN      2.0  Jakarta Timur
# 116  22-11-2021  220.0  239.0  5.0  4.0     1.0      2.0  Jakarta Timur
# 117  06-12-2021   70.0   57.0  3.0  2.0     NaN      2.0  Jakarta Timur
# 118  06-12-2021  315.0  280.0  4.0  3.0     1.0      2.0  Jakarta Timur
# 119  06-12-2021  135.0  190.0  5.0  5.0     NaN      2.0  Jakarta Timur
# 120  06-12-2021  144.0  250.0  5.0  5.0     NaN      2.0  Jakarta Timur
#
#     sertifikat  listrik    hadap         harga  \
# 111        SHM   1300.0      NaN  6.900000e+08
# 112        SHM   2200.0      NaN  1.600000e+09
# 113  SHM + IMB   2200.0      NaN  1.150000e+09
# 114        SHM   2200.0      NaN  2.465000e+09
# 115        SHM   2200.0      NaN  1.398000e+09
# 116       PPJB   3500.0      NaN  3.850000e+09
# 117        SHM   2200.0      NaN  8.800000e+08
# 118  SHM + IMB   3500.0    Timur  4.300000e+09
# 119  SHM + IMB   2200.0  Selatan  3.400000e+09
# 120        SHM   3500.0    Timur  2.250000e+09
#
#                                                    URL  \
# 111  https://www.rumah123.com/properti/jakarta-timu...
# 112  https://www.rumah123.com/properti/jakarta-timu...
# 113  https://www.rumah.com/listing-properti/dijual-...
# 114  https://www.rumah.com/listing-properti/dijual-...
# 115  https://www.rumah.com/listing-properti/dijual-...
# 116  https://www.rumah.com/listing-properti/dijual-...
# 117  https://www.rumah.com/listing-properti/dijual-...
# 118  https://www.rumah.com/listing-properti/dijual-...
# 119  https://www.rumah.com/listing-properti/dijual-...
# 120  https://www.rumah.com/listing-properti/dijual-...
#
#                                              deskripsi
# 111  Rumah Cluster 1 lantai. 10 menit ke stasiun LR...
# 112  Rumah Minimalis Modern 2 lantai, semi furnishe...
# 113  Rumah baru 2 lantai strategis di Kp Tengah Kra...
# 114  Rumah full furnished, fasilitas : water toren,...
# 115  Rumah 2 Lantai Legalitas Pecah Perkavling, Fas...
# 116  Rumah Mewah siap huni 2 lantai 220m 10x22 type...
# 117  Rumah Signature Location & Access :\n• 2 Menit...
# 118  Rumah 1, 5 Lantai Luas Strategis di Pondok Bam...
# 119  Rumah Baru Non Komplek Posisi Hook Lokasi Stra...
# 120  Rumah Modern Minimalis dengan 2 lantai di Jati...

# %%
bagus = dfJ1.drop_duplicates(subset='URL', keep="first")
bagus
#pengecekan apakah ada data duplikat apa tidak
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 0    06-12-2021  202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat
# 1    02-12-2021   30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat
# 2    06-12-2021   19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat
# 3    06-12-2021   33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# 4    06-12-2021   30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat
# ..          ...    ...    ...  ...  ...     ...      ...            ...
# 116  22-11-2021  220.0  239.0  5.0  4.0     1.0      2.0  Jakarta Timur
# 117  06-12-2021   70.0   57.0  3.0  2.0     NaN      2.0  Jakarta Timur
# 118  06-12-2021  315.0  280.0  4.0  3.0     1.0      2.0  Jakarta Timur
# 119  06-12-2021  135.0  190.0  5.0  5.0     NaN      2.0  Jakarta Timur
# 120  06-12-2021  144.0  250.0  5.0  5.0     NaN      2.0  Jakarta Timur
#
#     sertifikat  listrik    hadap         harga  \
# 0          SHM   2200.0      NaN  4.500000e+09
# 1          SHM   2200.0      NaN  1.100000e+09
# 2          SHM   2200.0      NaN  3.950000e+08
# 3          SHM   2200.0      NaN  8.350000e+08
# 4          SHM   2200.0      NaN  1.100000e+09
# ..         ...      ...      ...           ...
# 116       PPJB   3500.0      NaN  3.850000e+09
# 117        SHM   2200.0      NaN  8.800000e+08
# 118  SHM + IMB   3500.0    Timur  4.300000e+09
# 119  SHM + IMB   2200.0  Selatan  3.400000e+09
# 120        SHM   3500.0    Timur  2.250000e+09
#
#                                                    URL  \
# 0    https://www.rumah.com/listing-properti/dijual-...
# 1    https://www.rumah.com/listing-properti/dijual-...
# 2    https://www.rumah.com/listing-properti/dijual-...
# 3    https://www.rumah.com/listing-properti/dijual-...
# 4    https://www.rumah.com/listing-properti/dijual-...
# ..                                                 ...
# 116  https://www.rumah.com/listing-properti/dijual-...
# 117  https://www.rumah.com/listing-properti/dijual-...
# 118  https://www.rumah.com/listing-properti/dijual-...
# 119  https://www.rumah.com/listing-properti/dijual-...
# 120  https://www.rumah.com/listing-properti/dijual-...
#
#                                              deskripsi
# 0    Dekat Cikini Salemba Taman Isamail Marzuki Kam...
# 1    Mengusung konsep minimalis, dan didukung denga...
# 2    Dekat dengan Mall Atrium Senen, dekat dengan a...
# 3    Berlokasi sangat strategis, sangat dekat ke Tu...
# 4    Bisa request ubah tata ruang, beli 2 unit mend...
# ..                                                 ...
# 116  Rumah Mewah siap huni 2 lantai 220m 10x22 type...
# 117  Rumah Signature Location & Access :\n• 2 Menit...
# 118  Rumah 1, 5 Lantai Luas Strategis di Pondok Bam...
# 119  Rumah Baru Non Komplek Posisi Hook Lokasi Stra...
# 120  Rumah Modern Minimalis dengan 2 lantai di Jati...
#
# [120 rows x 14 columns]

# %%
dfJ2 = dfJ1.drop(['created_at', 'deskripsi', 'URL'], axis=1)
dfJ2
#drop variabel yang kira-kira tidak penting
# Out:
#         LT     LB   KT   KM  garasi  carport         lokasi sertifikat  \
# 0    202.0  198.0  8.0  3.0     NaN      NaN  Jakarta Pusat        SHM
# 1     30.0   55.0  2.0  1.0     NaN      1.0  Jakarta Pusat        SHM
# 2     19.0   35.0  2.0  1.0     NaN      NaN  Jakarta Pusat        SHM
# 3     33.0   42.0  2.0  2.0     NaN      1.0  Jakarta Pusat        SHM
# 4     30.0   55.0  2.0  2.0     NaN      1.0  Jakarta Pusat        SHM
# ..     ...    ...  ...  ...     ...      ...            ...        ...
# 116  220.0  239.0  5.0  4.0     1.0      2.0  Jakarta Timur       PPJB
# 117   70.0   57.0  3.0  2.0     NaN      2.0  Jakarta Timur        SHM
# 118  315.0  280.0  4.0  3.0     1.0      2.0  Jakarta Timur  SHM + IMB
# 119  135.0  190.0  5.0  5.0     NaN      2.0  Jakarta Timur  SHM + IMB
# 120  144.0  250.0  5.0  5.0     NaN      2.0  Jakarta Timur        SHM
#
#      listrik    hadap         harga
# 0     2200.0      NaN  4.500000e+09
# 1     2200.0      NaN  1.100000e+09
# 2     2200.0      NaN  3.950000e+08
# 3     2200.0      NaN  8.350000e+08
# 4     2200.0      NaN  1.100000e+09
# ..       ...      ...           ...
# 116   3500.0      NaN  3.850000e+09
# 117   2200.0      NaN  8.800000e+08
# 118   3500.0    Timur  4.300000e+09
# 119   2200.0  Selatan  3.400000e+09
# 120   3500.0    Timur  2.250000e+09
#
# [121 rows x 11 columns]

# %%
hargaJakarta = dfJ2['harga']
N, P = dfJ2.shape

harga = []
for i in range(N):
  harga.append('Jakarta')

dfJ2['Category'] = harga
dfJ2.tail()
# Out:
#         LT     LB   KT   KM  garasi  carport         lokasi sertifikat  \
# 116  220.0  239.0  5.0  4.0     1.0      2.0  Jakarta Timur       PPJB
# 117   70.0   57.0  3.0  2.0     NaN      2.0  Jakarta Timur        SHM
# 118  315.0  280.0  4.0  3.0     1.0      2.0  Jakarta Timur  SHM + IMB
# 119  135.0  190.0  5.0  5.0     NaN      2.0  Jakarta Timur  SHM + IMB
# 120  144.0  250.0  5.0  5.0     NaN      2.0  Jakarta Timur        SHM
#
#      listrik    hadap         harga Category
# 116   3500.0      NaN  3.850000e+09  Jakarta
# 117   2200.0      NaN  8.800000e+08  Jakarta
# 118   3500.0    Timur  4.300000e+09  Jakarta
# 119   2200.0  Selatan  3.400000e+09  Jakarta
# 120   3500.0    Timur  2.250000e+09  Jakarta

# %% [markdown]
# # Bogor

# %%
dfB.head(10)
# Out:
#    created_at     LT     LB   KT   KM  garasi  carport          lokasi  \
# 0  03-12-2021   75.0   38.0  2.0  1.0     1.0      1.0      Bojonggede
# 1  06-12-2021   60.0   40.0  1.0  1.0     0.0      1.0  Babakan Madang
# 2  06-12-2021   60.0   50.0  2.0  2.0     0.0      1.0  Babakan Madang
# 3  06-12-2021   60.0   70.0  3.0  2.0     0.0      1.0  Babakan Madang
# 4  06-12-2021   90.0   60.0  3.0  2.0     0.0      2.0  Babakan Madang
# 5  06-12-2021  120.0   70.0  3.0  2.0     0.0      2.0  Babakan Madang
# 6  06-12-2021  125.0  125.0  3.0  2.0     0.0      2.0  Babakan Madang
# 7  06-12-2021   97.0   72.0  3.0  2.0     0.0      1.0        Cibinong
# 8  06-12-2021   72.0   33.0  2.0  1.0     0.0      1.0    Gunung Putri
# 9  06-12-2021   60.0   30.0  2.0  1.0     0.0      1.0    Gunung Putri
#
#   sertifikat  listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0        SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 1        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 2        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 3        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 4        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 5        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 6        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 7        SHM   2200.0  ...         NaN          NaN         NaN         NaN
# 8        SHM   1300.0  ...         NaN          NaN         NaN         NaN
# 9        SHM   1300.0  ...         NaN          NaN         NaN         NaN
#
#    Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 25
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
#
# [10 rows x 26 columns]

# %%
#Menghapus kolom NaN
dfB.drop(dfB.iloc[:,14:], axis=1, inplace=True)
dfB.columns
# Out:
# Index(['created_at', 'LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi',
#        'sertifikat', 'listrik', 'hadap', 'harga', 'URL', 'deskripsi'],
#       dtype='object')

# %%
#drop data yang kosong
dfB1 = dfB.iloc[:193,:]
dfB1.tail(10)
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport          lokasi  \
# 183  03-12-2021  120.0   70.0  3.0  2.0     0.0      2.0  Babakan Madang
# 184  03-12-2021   84.0   36.0  2.0  1.0     0.0      2.0     Tajurhalang
# 185  03-12-2021  100.0   72.0  3.0  2.0     0.0      2.0    Gunung Putri
# 186  03-12-2021   72.0   36.0  2.0  1.0     0.0      1.0      Bojonggede
# 187  03-12-2021   72.0   36.0  2.0  1.0     0.0      1.0          Parung
# 188  03-12-2021   90.0   36.0  2.0  1.0     0.0      1.0    Gunung Putri
# 189  03-12-2021  107.0   31.0  2.0  1.0     0.0      1.0        Sukaraja
# 190  03-12-2021  210.0  150.0  4.0  2.0     1.0      1.0   Bogor Selatan
# 191  03-12-2021   90.0   36.0  2.0  1.0     0.0      1.0       Cileungsi
# 192  03-12-2021   72.0   90.0  3.0  2.0     1.0      1.0        Cibinong
#
#     sertifikat  listrik hadap         harga  \
# 183        SHM   2200.0   NaN  1.500000e+09
# 184        SHM   1300.0   NaN  3.902000e+08
# 185        SHM   2200.0   NaN  1.300000e+09
# 186       SHGB   1300.0   NaN  4.000000e+08
# 187        SHM   1300.0   NaN  4.195300e+08
# 188        SHM   1300.0   NaN  4.405500e+08
# 189        SHM   1300.0   NaN  4.086500e+08
# 190        SHM   2200.0   NaN  1.200000e+09
# 191        SHM   1300.0   NaN  4.405500e+08
# 192        SHM   2200.0   NaN  9.000000e+08
#
#                                                    URL  \
# 183  https://www.rumah.com/listing-properti/dijual-...
# 184  https://www.rumah.com/listing-properti/dijual-...
# 185  https://www.rumah.com/listing-properti/dijual-...
# 186  https://www.rumah.com/listing-properti/dijual-...
# 187  https://www.rumah.com/listing-properti/dijual-...
# 188  https://www.rumah.com/listing-properti/dijual-...
# 189  https://www.rumah.com/listing-properti/dijual-...
# 190  https://www.rumah.com/listing-properti/dijual-...
# 191  https://www.rumah.com/listing-properti/dijual-...
# 192  https://www.rumah.com/listing-properti/dijual-...
#
#                                              deskripsi
# 183  Dekat LRT Babakan Madang (bisa jalan kaki), 5 ...
# 184      One Gate System, Free taman depan, Playground
# 185    Pusat pendidikan, Gate toll Kota wisata cibubur
# 186  5 menit ke stasiun Bojong Gede, 10 menit dari ...
# 187                         Taman, Children Playground
# 188      Dekat taman buah mekarsari, dekat rumah sakit
# 189                                    Rumah siap huni
# 190                              Cuma 10 menit ke kota
# 191                     Dekat rumah sakit, dekat pasar
# 192                        Nyaman, aman, swimming pool

# %%
#Melihat data duplicate
print(dfB1.shape)
dfB1.duplicated().sum()
# Out:
# (193, 14)
# 0

# %%
#Mengubah data float menjadi category
dfB1['lokasi'] = dfB1['lokasi'].astype('category')
dfB1['sertifikat'] = dfB1['sertifikat'].astype('category')
dfB1['hadap'] = dfB1['hadap'].astype('category')
dfB1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  193 non-null    object
#  1   LT          193 non-null    float64
#  2   LB          193 non-null    float64
#  3   KT          193 non-null    float64
#  4   KM          193 non-null    float64
#  5   garasi      193 non-null    float64
#  6   carport     193 non-null    float64
#  7   lokasi      193 non-null    category
#  8   sertifikat  193 non-null    category
#  9   listrik     193 non-null    float64
#  10  hadap       19 non-null     category
#  11  harga       193 non-null    float64
#  12  URL         193 non-null    object
#  13  deskripsi   193 non-null    object
# dtypes: category(3), float64(8), object(3)
# memory usage: 19.0+ KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#Membuat kolom category untuk lokasi
hargaDepok= dfB1['harga']
N, P = dfB1.shape

harga = []
for i in range(N):
  harga.append('Bogor')

dfB1['Category'] = harga
dfB1.tail()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#      created_at     LT     LB   KT   KM  garasi  carport         lokasi  \
# 188  03-12-2021   90.0   36.0  2.0  1.0     0.0      1.0   Gunung Putri
# 189  03-12-2021  107.0   31.0  2.0  1.0     0.0      1.0       Sukaraja
# 190  03-12-2021  210.0  150.0  4.0  2.0     1.0      1.0  Bogor Selatan
# 191  03-12-2021   90.0   36.0  2.0  1.0     0.0      1.0      Cileungsi
# 192  03-12-2021   72.0   90.0  3.0  2.0     1.0      1.0       Cibinong
#
#     sertifikat  listrik hadap         harga  \
# 188        SHM   1300.0   NaN  4.405500e+08
# 189        SHM   1300.0   NaN  4.086500e+08
# 190        SHM   2200.0   NaN  1.200000e+09
# 191        SHM   1300.0   NaN  4.405500e+08
# 192        SHM   2200.0   NaN  9.000000e+08
#
#                                                    URL  \
# 188  https://www.rumah.com/listing-properti/dijual-...
# 189  https://www.rumah.com/listing-properti/dijual-...
# 190  https://www.rumah.com/listing-properti/dijual-...
# 191  https://www.rumah.com/listing-properti/dijual-...
# 192  https://www.rumah.com/listing-properti/dijual-...
#
#                                          deskripsi Category
# 188  Dekat taman buah mekarsari, dekat rumah sakit    Bogor
# 189                                Rumah siap huni    Bogor
# 190                          Cuma 10 menit ke kota    Bogor
# 191                 Dekat rumah sakit, dekat pasar    Bogor
# 192                    Nyaman, aman, swimming pool    Bogor

# %%
#Menghapus kolom yang kira-kira tidak penting
dfB2 = dfB1.drop(['created_at', 'deskripsi', 'URL'], axis=1)
dfB2
# Out:
#         LT     LB   KT   KM  garasi  carport          lokasi sertifikat  \
# 0     75.0   38.0  2.0  1.0     1.0      1.0      Bojonggede        SHM
# 1     60.0   40.0  1.0  1.0     0.0      1.0  Babakan Madang        SHM
# 2     60.0   50.0  2.0  2.0     0.0      1.0  Babakan Madang        SHM
# 3     60.0   70.0  3.0  2.0     0.0      1.0  Babakan Madang        SHM
# 4     90.0   60.0  3.0  2.0     0.0      2.0  Babakan Madang        SHM
# ..     ...    ...  ...  ...     ...      ...             ...        ...
# 188   90.0   36.0  2.0  1.0     0.0      1.0    Gunung Putri        SHM
# 189  107.0   31.0  2.0  1.0     0.0      1.0        Sukaraja        SHM
# 190  210.0  150.0  4.0  2.0     1.0      1.0   Bogor Selatan        SHM
# 191   90.0   36.0  2.0  1.0     0.0      1.0       Cileungsi        SHM
# 192   72.0   90.0  3.0  2.0     1.0      1.0        Cibinong        SHM
#
#      listrik  hadap         harga Category
# 0     1300.0  Barat  6.925500e+08    Bogor
# 1     2200.0    NaN  8.114000e+08    Bogor
# 2     2200.0    NaN  9.005000e+08    Bogor
# 3     2200.0    NaN  1.001900e+09    Bogor
# 4     2200.0    NaN  1.200800e+09    Bogor
# ..       ...    ...           ...      ...
# 188   1300.0    NaN  4.405500e+08    Bogor
# 189   1300.0    NaN  4.086500e+08    Bogor
# 190   2200.0    NaN  1.200000e+09    Bogor
# 191   1300.0    NaN  4.405500e+08    Bogor
# 192   2200.0    NaN  9.000000e+08    Bogor
#
# [193 rows x 12 columns]

# %% [markdown]
# # Tangerang

# %%
dfT.head()
dfT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   created_at   124 non-null    object
#  1   LT           124 non-null    float64
#  2   LB           124 non-null    float64
#  3   KT           124 non-null    float64
#  4   KM           124 non-null    float64
#  5   garasi       38 non-null     float64
#  6   carport      92 non-null     float64
#  7   lokasi       124 non-null    object
#  8   sertifikat   122 non-null    object
#  9   listrik      111 non-null    float64
#  10  hadap        49 non-null     object
#  11  harga        124 non-null    float64
#  12  URL          124 non-null    object
#  13  deskripsi    124 non-null    object
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
#  18  Unnamed: 18  0 non-null      float64
#  19  Unnamed: 19  0 non-null      float64
#  20  Unnamed: 20  0 non-null      float64
#  21  Unnamed: 21  0 non-null      float64
#  22  Unnamed: 22  0 non-null      float64
#  23  Unnamed: 23  0 non-null      float64
#  24  Unnamed: 24  0 non-null      float64
#  25  Unnamed: 25  0 non-null      float64
# dtypes: float64(20), object(6)
# memory usage: 26.1+ KB

# %%
dfT.drop(dfT.iloc[:,14:], axis=1, inplace=True)
dfT.columns
# Out:
# Index(['created_at', 'LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi',
#        'sertifikat', 'listrik', 'hadap', 'harga', 'URL', 'deskripsi'],
#       dtype='object')

# %%
dfT = dfT.iloc[:124,:]
dfT.tail(10)
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport  \
# 114  12-08-2021  276.0  441.0  4.0  4.0     4.0      4.0
# 115  12-08-2021   66.0   37.0  2.0  1.0     1.0      1.0
# 116  12-08-2021  118.0   88.0  3.0  2.0     NaN      NaN
# 117  12-08-2021  144.0  240.0  4.0  2.0     NaN      1.0
# 118  12-08-2021  300.0  148.0  4.0  3.0     2.0      2.0
# 119  12-08-2021   60.0   55.0  2.0  2.0     NaN      1.0
# 120  12-08-2021   66.0   70.0  3.0  2.0     NaN      1.0
# 121  12-08-2021  202.0   85.0  4.0  3.0     1.0      1.0
# 122  12-08-2021  108.0  130.0  3.0  3.0     1.0      1.0
# 123  12-08-2021   91.0   91.0  3.0  2.0     NaN      NaN
#
#                         lokasi                       sertifikat  listrik  \
# 114             BSD, TANGERANG                              SHM  11000.0
# 115          CISAUK, TANGERANG                              SHM   1300.0
# 116  GADING SERPONG, TANGERANG  lainnya(PPJB, GIRIK, ADAT, dll)   2200.0
# 117  GADING SERPONG, TANGERANG                              SHM   2200.0
# 118     PONDOK CABE, TANGERANG                              SHM   2200.0
# 119  LIPPO KARAWACI, TANGERANG  lainnya(PPJB, GIRIK, ADAT, dll)   2200.0
# 120          Ciater, Tangerang                              SHM   1300.0
# 121  BSD Griya Loka, Tangerang                              SHM   2200.0
# 122      Pagedangan, Tangerang                              SHM   2200.0
# 123           Poris, Tangerang                              SHM   3500.0
#
#        hadap    harga                                                URL  \
# 114      NaN  13000.0  https://www.rumah123.com/properti/tangerang/ho...
# 115      NaN    221.0  https://www.rumah123.com/properti/tangerang/ho...
# 116      NaN   2300.0  https://www.rumah123.com/properti/tangerang/ho...
# 117  Selatan   2800.0  https://www.rumah123.com/properti/tangerang/ho...
# 118    Timur   1900.0  https://www.rumah123.com/properti/tangerang/ho...
# 119      NaN    711.0  https://www.rumah123.com/properti/tangerang/ho...
# 120      NaN    850.0  https://www.rumah123.com/properti/tangerang/ho...
# 121    Barat   1860.0  https://www.rumah123.com/properti/tangerang/ho...
# 122      NaN   1800.0  https://www.rumah123.com/properti/tangerang/ho...
# 123      NaN   1000.0  https://www.rumah123.com/properti/tangerang/ho...
#
#                                              deskripsi
# 114  LAUREL NAVAPARK @ BSD City Tangerang Phase2. D...
# 115  5 juta sudah berkesempatan dapat rumah murah y...
# 116  Rumah Dijual Tangerang HOEK, CLUSTER , TERMASU...
# 117  Bisa Nego, Full furnished, Lokasi strategis, F...
# 118  DIJUAL DI BAWAH HARGA PASAR, HARGA PASARAN MAS...
# 119  Lokasi sangat dekat dengan berbagai Akses,Ters...
# 120  Berlian Ciater, Hunian 2 Lantai Nyaman dan Asr...
# 121  1-7 km ke Stasiun Rawa Buntu, Rs Eka Hospital,...
# 122  Fasilitas Terdekat :Lokasi strategis, berada d...
# 123  Akses Mudah: 10 Menit Ke stasiun kereta poris ...

# %%
dfT.duplicated().sum()
# Out:
# 0

# %%
df = np.abs(dfT.harga - dfT.harga.mean())<=(2*dfT.harga.std())
# mu-2s<x<mu+2s
print(df.shape)
df.head()
dfT2 = dfT[df] # Data tanpa outliers
print(dfT2.shape, dfT.shape)
# Out:
# (124,)
# (123, 14) (124, 14)

# %%
hargaTangerang= dfT2['harga']
N, P = dfT2.shape

harga = []
for i in range(N):
  harga.append('Tangerang')

dfT2['Category'] = harga
dfT2.tail()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      created_at     LT     LB   KT   KM  garasi  carport  \
# 119  12-08-2021   60.0   55.0  2.0  2.0     NaN      1.0
# 120  12-08-2021   66.0   70.0  3.0  2.0     NaN      1.0
# 121  12-08-2021  202.0   85.0  4.0  3.0     1.0      1.0
# 122  12-08-2021  108.0  130.0  3.0  3.0     1.0      1.0
# 123  12-08-2021   91.0   91.0  3.0  2.0     NaN      NaN
#
#                         lokasi                       sertifikat  listrik  \
# 119  LIPPO KARAWACI, TANGERANG  lainnya(PPJB, GIRIK, ADAT, dll)   2200.0
# 120          Ciater, Tangerang                              SHM   1300.0
# 121  BSD Griya Loka, Tangerang                              SHM   2200.0
# 122      Pagedangan, Tangerang                              SHM   2200.0
# 123           Poris, Tangerang                              SHM   3500.0
#
#      hadap   harga                                                URL  \
# 119    NaN   711.0  https://www.rumah123.com/properti/tangerang/ho...
# 120    NaN   850.0  https://www.rumah123.com/properti/tangerang/ho...
# 121  Barat  1860.0  https://www.rumah123.com/properti/tangerang/ho...
# 122    NaN  1800.0  https://www.rumah123.com/properti/tangerang/ho...
# 123    NaN  1000.0  https://www.rumah123.com/properti/tangerang/ho...
#
#                                              deskripsi   Category
# 119  Lokasi sangat dekat dengan berbagai Akses,Ters...  Tangerang
# 120  Berlian Ciater, Hunian 2 Lantai Nyaman dan Asr...  Tangerang
# 121  1-7 km ke Stasiun Rawa Buntu, Rs Eka Hospital,...  Tangerang
# 122  Fasilitas Terdekat :Lokasi strategis, berada d...  Tangerang
# 123  Akses Mudah: 10 Menit Ke stasiun kereta poris ...  Tangerang

# %% [markdown]
# # Bekasi

# %%
dfX.drop(dfX.iloc[:,14:], axis=1, inplace=True)
dfX.columns
# Out:
# Index(['created_at', 'LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi',
#        'sertifikat', 'listrik', 'hadap', 'harga', 'URL', 'deskripsi'],
#       dtype='object')

# %%
dfX1 = dfX.iloc[:107,:]
dfX1.tail()
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport            lokasi  \
# 102  01-12-2021  180.0  220.0  5.0  3.0     NaN      NaN       Kota Bekasi
# 103  01-12-2021  140.0  250.0  3.0  2.0     NaN      NaN  Kabupaten Bekasi
# 104  01-12-2021   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
# 105  01-12-2021   36.0   60.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
# 106  01-12-2021   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
#
#     sertifikat  listrik    hadap         harga  \
# 102        SHM   2200.0      NaN  1.600000e+09
# 103        SHM   2200.0  Selatan  8.500000e+08
# 104        SHM   1300.0      NaN  2.500000e+08
# 105        SHM   1300.0    Timur  3.000000e+08
# 106        SHM   1300.0      NaN  2.500000e+08
#
#                                                    URL  \
# 102  https://www.rumah123.com/properti/bekasi/hos92...
# 103  https://www.rumah123.com/properti/bekasi/hos92...
# 104  https://www.rumah123.com/properti/bekasi/hos92...
# 105  https://www.rumah123.com/properti/bekasi/hos92...
# 106  https://www.rumah123.com/properti/bekasi/hos92...
#
#                                              deskripsi
# 102  Akses pintu tol Bekasibarat; Dekat Mall Summar...
# 103  DIJUAL RUMAH, Taman Kebalen bekasi cluster, Ju...
# 104  Di jual Rumah Lelang Bank Pondok Ungu Permai, ...
# 105  Lokasi Super Strategis, Selangkah menuju Kota ...
# 106  RCG/20/V/010 MP/LB/THM/010 Di jual Rumah Lelan...

# %%
bagusbekasi = dfX1.drop_duplicates(subset='URL', keep="first")
bagusbekasi
# Out:
#      created_at     LT     LB   KT   KM  garasi  carport            lokasi  \
# 0    08-12-2021   71.0   43.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 1    08-12-2021   59.0   60.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 2    08-12-2021  124.0   95.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 3    08-12-2021  144.0  100.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi
# 4    08-12-2021  108.0  100.0  3.0  2.0     NaN      1.0  Kabupaten Bekasi
# ..          ...    ...    ...  ...  ...     ...      ...               ...
# 101  01-12-2021  108.0   47.0  2.0  1.0     NaN      1.0       Kota Bekasi
# 102  01-12-2021  180.0  220.0  5.0  3.0     NaN      NaN       Kota Bekasi
# 103  01-12-2021  140.0  250.0  3.0  2.0     NaN      NaN  Kabupaten Bekasi
# 104  01-12-2021   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
# 105  01-12-2021   36.0   60.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi
#
#     sertifikat  listrik    hadap         harga  \
# 0          SHM   1300.0      NaN  5.500000e+08
# 1          SHM      NaN      NaN  4.400000e+08
# 2          SHM      NaN      NaN  6.990000e+08
# 3          SHM   2200.0  Selatan  1.350000e+09
# 4          SHM   2200.0    Timur  1.400000e+09
# ..         ...      ...      ...           ...
# 101        SHM   1300.0      NaN  1.000000e+09
# 102        SHM   2200.0      NaN  1.600000e+09
# 103        SHM   2200.0  Selatan  8.500000e+08
# 104        SHM   1300.0      NaN  2.500000e+08
# 105        SHM   1300.0    Timur  3.000000e+08
#
#                                                    URL  \
# 0    Rumah murah di metland cibitung bekasi - Dijua...
# 1    Rumah dijual di Griya gandasari cibitung - Dij...
# 2    Jual cepat rumah huuk di metland cibitung beka...
# 3    https://www.realoka.com/216243-rumah-rapi-siap...
# 4    https://www.realoka.com/207964-jual-rumah-bagu...
# ..                                                 ...
# 101  https://www.rumah123.com/properti/bekasi/hos92...
# 102  https://www.rumah123.com/properti/bekasi/hos92...
# 103  https://www.rumah123.com/properti/bekasi/hos92...
# 104  https://www.rumah123.com/properti/bekasi/hos92...
# 105  https://www.rumah123.com/properti/bekasi/hos92...
#
#                                              deskripsi
# 0    Selangkah ke stasiun krl telaga murni, Dekat d...
# 1    Rumah sangat nyaman,dan terbukti bebas banjir,...
# 2    Bebas banjir, Carport dan tanah luas ada taman...
# 3    (Harapan Indah) Cluster Aralia Kota Harapan In...
# 4    (Harapan Indah) Cluster Harmoni Perumahan Kota...
# ..                                                 ...
# 101  Rumah siap,di salah satu cluster grand wisata,...
# 102  Akses pintu tol Bekasibarat; Dekat Mall Summar...
# 103  DIJUAL RUMAH, Taman Kebalen bekasi cluster, Ju...
# 104  Di jual Rumah Lelang Bank Pondok Ungu Permai, ...
# 105  Lokasi Super Strategis, Selangkah menuju Kota ...
#
# [104 rows x 14 columns]

# %%
dfX2 = dfX1.drop(['created_at', 'deskripsi', 'URL'], axis=1)
dfX2
# Out:
#         LT     LB   KT   KM  garasi  carport            lokasi sertifikat  \
# 0     71.0   43.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi        SHM
# 1     59.0   60.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi        SHM
# 2    124.0   95.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi        SHM
# 3    144.0  100.0  2.0  1.0     NaN      1.0  Kabupaten Bekasi        SHM
# 4    108.0  100.0  3.0  2.0     NaN      1.0  Kabupaten Bekasi        SHM
# ..     ...    ...  ...  ...     ...      ...               ...        ...
# 102  180.0  220.0  5.0  3.0     NaN      NaN       Kota Bekasi        SHM
# 103  140.0  250.0  3.0  2.0     NaN      NaN  Kabupaten Bekasi        SHM
# 104   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi        SHM
# 105   36.0   60.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi        SHM
# 106   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi        SHM
#
#      listrik    hadap         harga
# 0     1300.0      NaN  5.500000e+08
# 1        NaN      NaN  4.400000e+08
# 2        NaN      NaN  6.990000e+08
# 3     2200.0  Selatan  1.350000e+09
# 4     2200.0    Timur  1.400000e+09
# ..       ...      ...           ...
# 102   2200.0      NaN  1.600000e+09
# 103   2200.0  Selatan  8.500000e+08
# 104   1300.0      NaN  2.500000e+08
# 105   1300.0    Timur  3.000000e+08
# 106   1300.0      NaN  2.500000e+08
#
# [107 rows x 11 columns]

# %%
hargaBekasi = dfX2['harga']
N, P = dfX2.shape

harga = []
for i in range(N):
  harga.append('Bekasi')

dfX2['Category'] = harga
dfX2.tail()
# Out:
#         LT     LB   KT   KM  garasi  carport            lokasi sertifikat  \
# 102  180.0  220.0  5.0  3.0     NaN      NaN       Kota Bekasi        SHM
# 103  140.0  250.0  3.0  2.0     NaN      NaN  Kabupaten Bekasi        SHM
# 104   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi        SHM
# 105   36.0   60.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi        SHM
# 106   60.0   55.0  2.0  1.0     NaN      NaN  Kabupaten Bekasi        SHM
#
#      listrik    hadap         harga Category
# 102   2200.0      NaN  1.600000e+09   Bekasi
# 103   2200.0  Selatan  8.500000e+08   Bekasi
# 104   1300.0      NaN  2.500000e+08   Bekasi
# 105   1300.0    Timur  3.000000e+08   Bekasi
# 106   1300.0      NaN  2.500000e+08   Bekasi

# %%
print(dfX1.shape)
dfX1.duplicated().sum()
# Out:
# (107, 14)
# 0

# %%
dfX['lokasi'] = dfX['lokasi'].astype('category')
dfX['sertifikat'] = dfX['sertifikat'].astype('category')
dfX['hadap'] = dfX['hadap'].astype('category')
dfX.dtypes
# Out:
# created_at      object
# LT             float64
# LB             float64
# KT             float64
# KM             float64
# garasi         float64
# carport        float64
# lokasi        category
# sertifikat    category
# listrik        float64
# hadap         category
# harga          float64
# URL             object
# deskripsi       object
# dtype: object

# %% [markdown]
# #Depok#

# %%
dfD.sample(10)
# Out:
#     created_at   LT  LB  KT  KM  garasi  carport lokasi sertifikat  listrik  \
# 171        NaN  NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 749        NaN  NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 397        NaN  NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 141        NaN  NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 501        NaN  NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 420        NaN  NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 632        NaN  NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 892        NaN  NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 912        NaN  NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
# 681        NaN  NaN NaN NaN NaN     NaN      NaN    NaN        NaN      NaN
#
#      ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  Unnamed: 20  \
# 171  ...         NaN          NaN         NaN         NaN          NaN
# 749  ...         NaN          NaN         NaN         NaN          NaN
# 397  ...         NaN          NaN         NaN         NaN          NaN
# 141  ...         NaN          NaN         NaN         NaN          NaN
# 501  ...         NaN          NaN         NaN         NaN          NaN
# 420  ...         NaN          NaN         NaN         NaN          NaN
# 632  ...         NaN          NaN         NaN         NaN          NaN
# 892  ...         NaN          NaN         NaN         NaN          NaN
# 912  ...         NaN          NaN         NaN         NaN          NaN
# 681  ...         NaN          NaN         NaN         NaN          NaN
#
#      Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 171          NaN          NaN          NaN          NaN          NaN
# 749          NaN          NaN          NaN          NaN          NaN
# 397          NaN          NaN          NaN          NaN          NaN
# 141          NaN          NaN          NaN          NaN          NaN
# 501          NaN          NaN          NaN          NaN          NaN
# 420          NaN          NaN          NaN          NaN          NaN
# 632          NaN          NaN          NaN          NaN          NaN
# 892          NaN          NaN          NaN          NaN          NaN
# 912          NaN          NaN          NaN          NaN          NaN
# 681          NaN          NaN          NaN          NaN          NaN
#
# [10 rows x 26 columns]

# %%
dfD1 = dfD.iloc[:118,:]
dfD1.tail(10)
#menghilangkan baris yang kosong
# Out:
#     created_at   LT     LB   KT   KM  garasi  carport     lokasi sertifikat  \
# 108  4-12-2021   66   56.0  3.0  2.0     NaN      1.0  Cimanggis        SHM
# 109  4-12-2021   94   56.0  3.0  2.0     NaN      1.0  Cimanggis        SHM
# 110  4-12-2021  120  103.0  3.0  2.0     NaN      2.0  Cimanggis        SHM
# 111  4-12-2021   65   46.0  2.0  2.0     NaN      1.0  Cimanggis        SHM
# 112  4-12-2021   80   80.0  2.0  2.0     NaN      NaN   Cilodong        SHM
# 113  4-12-2021   79  115.0  2.0  1.0     1.0      1.0  Sukmajaya        SHM
# 114  4-12-2021   72   45.0  2.0  1.0     NaN      1.0  Cimanggis        SHM
# 115  4-12-2021   40   40.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 116  4-12-2021   50   50.0  2.0  1.0     NaN      NaN   Cipayung        SHM
# 117  4-12-2021  100   15.0  3.0  3.0     1.0      1.0     Cinere        SHM
#
#      listrik  ... Unnamed: 16  Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 108   2200.0  ...         NaN          NaN         NaN         NaN
# 109   2200.0  ...         NaN          NaN         NaN         NaN
# 110   2200.0  ...         NaN          NaN         NaN         NaN
# 111   2200.0  ...         NaN          NaN         NaN         NaN
# 112    900.0  ...         NaN          NaN         NaN         NaN
# 113      NaN  ...         NaN          NaN         NaN         NaN
# 114      NaN  ...         NaN          NaN         NaN         NaN
# 115   1300.0  ...         NaN          NaN         NaN         NaN
# 116   1300.0  ...         NaN          NaN         NaN         NaN
# 117   3500.0  ...         NaN          NaN         NaN         NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# 108          NaN          NaN          NaN          NaN          NaN
# 109          NaN          NaN          NaN          NaN          NaN
# 110          NaN          NaN          NaN          NaN          NaN
# 111          NaN          NaN          NaN          NaN          NaN
# 112          NaN          NaN          NaN          NaN          NaN
# 113          NaN          NaN          NaN          NaN          NaN
# 114          NaN          NaN          NaN          NaN          NaN
# 115          NaN          NaN          NaN          NaN          NaN
# 116          NaN          NaN          NaN          NaN          NaN
# 117          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 25
# 108          NaN
# 109          NaN
# 110          NaN
# 111          NaN
# 112          NaN
# 113          NaN
# 114          NaN
# 115          NaN
# 116          NaN
# 117          NaN
#
# [10 rows x 26 columns]

# %%
dfD1.drop(dfD1.iloc[:,14:], axis=1, inplace=True)
dfD1.columns
#menghilangkan kolom yang kosong
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# Index(['created_at', 'LT', 'LB', 'KT', 'KM', 'garasi', 'carport', 'lokasi',
#        'sertifikat', 'listrik', 'hadap', 'harga', 'URL', 'deskripsi'],
#       dtype='object')

# %%
dfD2= dfD1.drop_duplicates(subset='URL', keep="first")
#menghilangkan duplicates

# %%
N, P = dfD2.shape

harga = []
for i in range(N):
  harga.append('Depok')

dfD2['Category'] = harga
#menambahkan kategori untuk visualisasi

# %% [markdown]
# # Kualitas data Milik Perusahaan

# %% [markdown]
# kualitas data milik perusahaan:
# i) Kelengkapan data:
# Kelengkapan suatu data mengacu kepada seberapa komprehensif informasi. Faktor terpenting kelengkapan adalah untuk memastikan semua data yang dibutuhkan tersedia. Namun berdasarkan hasil penyelidikan kami, data yang disediakan oleh RPPI  memiliki banyak missing value di masing-masing baris dan kolom dalam data. Hal tersebut menyulitkan tim kami dalam menganalisis data dan memerlukan banyak waktu untuk membersihkan dan merapikan data yang diberikan.
#
# ii) Relevansi
# Informasi yang didapatkan tentunya memiliki alasan bagus mengapa informasi tertentu dikumpulkan. Sayangnya, berdasarkan analisa tim kami, kami menemukan banyaknya data-data yang dikumpulkan dan tidak relevan dalam penarikan keputusan, seperti data deskripsi, URL, dan created_at
#
# iii) Reabilitas
# Informasi yang didapatkan harus sesuai dengan data yang didapatkan pada lapangan, karena data yang salah dapat berakibat fatal. Berdasarkan hasil penelitian tim kami, data yang didapatkan oleh perusahaan RPPI sudah reliabel dikarenakan tim kami tidak menemukan adanya duplikat didalam keseluruhan dataframe. Namun, tim kami menemukan banyaknya outlier dalam data yang diberikan.
#
# Oleh karena itu, menurut analisa tim kami, kualitas data yang dimiliki perusahaan sudah cukup reliabel, namun memiliki beberapa variabel yang kurang relevan, dan data-data yang diberikan kurang lengkap.

# %% [markdown]
# # Saran Perbaikan kepada Perusahaan

# %% [markdown]
# Saran perbaikan data agar RPPI lebih unggul.
# i. Missing values
# Missing values dalam Big Data tidak jarang ditemukan, ada kasus dimana Missing values tidak bisa dihindari dan ada juga yang bisa dihindari. Sebagai contoh, untuk data garasi dan carport, apabila rumah tersebut tidak memiliki garasi/carport, sebaiknya diisi dengan angka 0.
#
# ii. Deskripsi
# Pendeskripsian dari masing-masing rumah tidak bisa dijelaskan dalam format yang sama persis. Tetapi akan lebih baik jika diberikan instruksi dalam pengisian kolom deskripsi, agar dalam database terlihat seragam. Contohnya adalah dalam pengisian deskripsi ada instruksi seperti "Berikan penjelasan mengenai rumah secara berurut dari a ke b ke c"

# %% [markdown]
# #Question 3

# %%
boxplot(category)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-252debb5d682> in <module>
# ----> 1 boxplot(category)
#
# NameError: name 'boxplot' is not defined
